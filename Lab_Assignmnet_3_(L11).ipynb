# %% [markdown]
# <a href="https://colab.research.google.com/github/hamdansethi/Programming-For-AI/blob/main/Lab_Assignmnet_3_(L10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name: HAMDAN KHALID SETHI
# Reg No.: SP23-BAI-015

# %%
rent = pd.read_csv("/content/HouseRent.csv")
rent.head()
# Out:
#     Posted On  BHK     Rent    Size            Floor    Area Type  \
# 0  2022-05-18    2  10000.0  1100.0  Ground out of 2   Super Area
# 1  2022-05-13    2  20000.0   800.0       1 out of 3   Super Area
# 2  2022-05-16    2  17000.0  1000.0       1 out of 3   Super Area
# 3  2022-07-04    2  10000.0   800.0       1 out of 2   Super Area
# 4  2022-05-09    2   7500.0   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# ...

# %%
rent.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
print(rent.isna().sum())
# Out:
# Posted On            0
# BHK                  0
# Rent                 2
# Size                 1
# Floor                0
# Area Type            0
# Area Locality        1
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
rent = rent.dropna()

# %%
print(rent.isna().sum())
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
rent_numeric = rent.select_dtypes(include=["number"])
stat = ["mean", "median", "std", "var", "max", "min", "quantile"]
rent_numeric.agg(stat)
# Out:
#                BHK          Rent           Size   Bathroom
# mean      2.083720  3.500251e+04     967.222902   1.965626
# median    2.000000  1.600000e+04     850.000000   2.000000
# std       0.832498  7.813745e+04     634.148041   0.884777
# var       0.693053  6.105461e+09  402143.737902   0.782830
# max       6.000000  3.500000e+06    8000.000000  10.000000
# min       1.000000  1.200000e+03      10.000000   1.000000
# quantile  2.000000  1.600000e+04     850.000000   2.000000

# %%
category_map = {'Carpet Area': 0, 'Built Area': 1, 'Super Area': 2}
rent['Area Type C'] = rent['Area Type'].map(category_map)
# Out:
# <ipython-input-208-4a075cc29418>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rent["Area Type"].unique()
# Out:
# array(['Super Area', 'Carpet Area', 'Built Area'], dtype=object)

# %%
rent.head()
# Out:
#     Posted On  BHK     Rent    Size            Floor    Area Type  \
# 0  2022-05-18    2  10000.0  1100.0  Ground out of 2   Super Area
# 1  2022-05-13    2  20000.0   800.0       1 out of 3   Super Area
# 2  2022-05-16    2  17000.0  1000.0       1 out of 3   Super Area
# 3  2022-07-04    2  10000.0   800.0       1 out of 2   Super Area
# 4  2022-05-09    2   7500.0   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact  Area Type C
# 0         2    Contact Owner            2
# 1         1    Contact Owner            2
# ...

# %%
plt.bar(rent["Area Type"], rent["Rent"])
plt.show()

# %%
plt.scatter(rent["Size"], rent["Rent"])
plt.show()

# %%
plt.boxplot(rent["Size"])
plt.show()

# %%
rent.boxplot(column = "Size", by = "Rent")
plt.show()

# %%
plt.figure(figsize=(10, 6))
rent.boxplot(column = "Size", by = "Area Type C")
plt.show()

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# **Series** -> Single Column / 1D Array
#
# **DataFrame** -> Table/ Multi Dimension Array

# %%
obj = pd.Series([30, 20, 10, 0])
obj
# Out:
# 0    30
# 1    20
# 2    10
# 3     0
# dtype: int64

# %%
obj = pd.Series([[30, 20, 10, 0],[20, 40, 60, 80]])
obj
# Out:
# 0     [30, 20, 10, 0]
# 1    [20, 40, 60, 80]
# dtype: object

# %%
obj.array
# Out:
# <NumpyExtensionArray>
# [[30, 20, 10, 0], [20, 40, 60, 80]]
# Length: 2, dtype: object

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
obj2 = pd.Series([30, 20, 10, 0], index=['a', 'b', 'c', 'd'])
obj2
# Out:
# a    30
# b    20
# c    10
# d     0
# dtype: int64

# %%
obj2["d"]
# Out:
# 0

# %%
obj2[["a", "b", "d"]]
# Out:
# a    30
# b    20
# d     0
# dtype: int64

# %%
obj2[obj2 >= 20]
# Out:
# a    30
# b    20
# dtype: int64

# %%
obj2[obj2 <= 20]
# Out:
# b    20
# c    10
# d     0
# dtype: int64

# %%
import pprint

# %%
#Dictionary to DataFrame

data = {
    "name" : ["Ali", "Ahmed", "Ahsan", "Aaina", "Zara"],
    "score" : [80, 70, 60, 90 , 95],
    "sports" : ["Cricket", "Hockey", "Tennis", "Volley Ball", "Swimming"],
    "gender" : ["M", "M", "M", "F", "F"]
}

pprint.pprint(data)
# Out:
# {'gender': ['M', 'M', 'M', 'F', 'F'],
#  'name': ['Ali', 'Ahmed', 'Ahsan', 'Aaina', 'Zara'],
#  'score': [80, 70, 60, 90, 95],
#  'sports': ['Cricket', 'Hockey', 'Tennis', 'Volley Ball', 'Swimming']}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     name  score       sports gender
# 0    Ali     80      Cricket      M
# 1  Ahmed     70       Hockey      M
# 2  Ahsan     60       Tennis      M
# 3  Aaina     90  Volley Ball      F
# 4   Zara     95     Swimming      F

# %%
purchase = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e'])
purchase
# Out:
#     name  score       sports gender
# a    Ali     80      Cricket      M
# b  Ahmed     70       Hockey      M
# c  Ahsan     60       Tennis      M
# d  Aaina     90  Volley Ball      F
# e   Zara     95     Swimming      F

# %%
fruits = {
    'Oranges' : [10,20,30,40,50],
    'Apples' : [19, 29, 39, 49, 59]
}

pprint.pprint(fruits)
# Out:
# {'Apples': [19, 29, 39, 49, 59], 'Oranges': [10, 20, 30, 40, 50]}

# %%
df = pd.DataFrame(fruits, index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
df
# Out:
#            Oranges  Apples
# Monday          10      19
# Tuesday         20      29
# Wednesday       30      39
# Thursday        40      49
# Friday          50      59

# %%
df.loc['Monday']
# Out:
# Oranges    10
# Apples     19
# Name: Monday, dtype: int64

# %%
df.head() # first 5 rows
# Out:
#            Oranges  Apples
# Monday          10      19
# Tuesday         20      29
# Wednesday       30      39
# Thursday        40      49
# Friday          50      59

# %%
df.head(2)
# Out:
#          Oranges  Apples
# Monday        10      19
# Tuesday       20      29

# %%
df.tail() #last 5 rows
# Out:
#            Oranges  Apples
# Monday          10      19
# Tuesday         20      29
# Wednesday       30      39
# Thursday        40      49
# Friday          50      59

# %%
df.shape
# Out:
# (5, 2)

# %%
df.shape[0]
# Out:
# 5

# %%
df.shape[1]
# Out:
# 2

# %%
df.index
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], dtype='object')

# %%
df.describe()
# Out:
#          Oranges     Apples
# count   5.000000   5.000000
# mean   30.000000  39.000000
# std    15.811388  15.811388
# min    10.000000  19.000000
# 25%    20.000000  29.000000
# 50%    30.000000  39.000000
# 75%    40.000000  49.000000
# max    50.000000  59.000000

# %%
df1 = pd.DataFrame(df, columns = ["Oranges", "Apples", "Banana", "Kiwi", "Lychee"])
df1
# Out:
#            Oranges  Apples  Banana  Kiwi  Lychee
# Monday          10      19     NaN   NaN     NaN
# Tuesday         20      29     NaN   NaN     NaN
# Wednesday       30      39     NaN   NaN     NaN
# Thursday        40      49     NaN   NaN     NaN
# Friday          50      59     NaN   NaN     NaN

# %%
df2 = pd.DataFrame(df, columns = ["Apples", "Banana"], index = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])
df2
# Out:
#            Apples  Banana
# Monday       19.0     NaN
# Tuesday      29.0     NaN
# Wednesday    39.0     NaN
# Thursday     49.0     NaN
# Friday       59.0     NaN
# Saturday      NaN     NaN
# Sunday        NaN     NaN

# %%
df2.loc[:,'Banana'] = [111, 222, 333, 444, 555, 666, 777]

# %%
df2
# Out:
#            Apples  Banana
# Monday       19.0   111.0
# Tuesday      29.0   222.0
# Wednesday    39.0   333.0
# Thursday     49.0   444.0
# Friday       59.0   555.0
# Saturday      NaN   666.0
# Sunday        NaN   777.0

# %%
df2["Banana"]
# Out:
# Monday       111.0
# Tuesday      222.0
# Wednesday    333.0
# Thursday     444.0
# Friday       555.0
# Saturday     666.0
# Sunday       777.0
# Name: Banana, dtype: float64

# %%
df2["Apples"] = [19, 29, 39, 49, 59, 69, 79 ]
df2
# Out:
#            Apples  Banana
# Monday         19   111.0
# Tuesday        29   222.0
# Wednesday      39   333.0
# Thursday       49   444.0
# Friday         59   555.0
# Saturday       69   666.0
# Sunday         79   777.0

# %%
df2.loc["Monday":"Wednesday"]
# Out:
#            Apples  Banana
# Monday         19   111.0
# Tuesday        29   222.0
# Wednesday      39   333.0

# %%
df2.loc[["Monday", "Wednesday"]]
# Out:
#            Apples  Banana
# Monday         19   111.0
# Wednesday      39   333.0

# %%
df2.loc["Monday"] = [99, 150]

# %%
df2
# Out:
#            Apples  Banana
# Monday         99   150.0
# Tuesday        29   222.0
# Wednesday      39   333.0
# Thursday       49   444.0
# Friday         59   555.0
# Saturday       69   666.0
# Sunday         79   777.0

# %%
df3 = pd.DataFrame(df2, columns = ["Apples", "Banana", "Kiwi"])
df3
# Out:
#            Apples  Banana  Kiwi
# Monday         99   150.0   NaN
# Tuesday        29   222.0   NaN
# Wednesday      39   333.0   NaN
# Thursday       49   444.0   NaN
# Friday         59   555.0   NaN
# Saturday       69   666.0   NaN
# Sunday         79   777.0   NaN

# %%
df3["Kiwi"] = [1, 2, 3, 4, 5, 6, 7] # Length Must be same
df3
# Out:
#            Apples  Banana  Kiwi
# Monday         99   150.0     1
# Tuesday        29   222.0     2
# Wednesday      39   333.0     3
# Thursday       49   444.0     4
# Friday         59   555.0     5
# Saturday       69   666.0     6
# Sunday         79   777.0     7

# %%
path = "/content/Iris.csv"

# %%
iris = pd.read_csv(path)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.Species.describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: Species, dtype: object

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
imdb_path = "/content/imdb.csv"

# %%
imdb_pandas = pd.read_csv(imdb_path)
imdb_pandas
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
imdb_np = imdb_pandas.to_numpy()
imdb_np
# Out:
# array([['https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg',
#         'The Shawshank Redemption', '1994', ..., 'William Sadler',
#         2343110, '28,341,469'],
#        ['https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg',
#         'The Godfather', '1972', ..., 'Diane Keaton', 1620367,
#         '134,966,411'],
#        ['https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#         'The Dark Knight', '2008', ..., 'Michael Caine', 2303232,
#         '534,858,444'],
#        ...,
#        ['https://m.media-amazon.com/images/M/MV5BM2U3YzkxNGMtYWE0YS00ODk0LTk1ZGEtNjk3ZTE0MTk4MzJjXkEyXkFqcGdeQXVyNDk0MDg4NDk@._V1_UX67_CR0,0,67,98_AL_.jpg',
#         'From Here to Eternity', '1953', ..., 'Donna Reed', 43374,
#         '30,500,000'],
# ...

# %%
imdb_pandas.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
imdb_pandas[["Series_Title","Certificate"]]
# Out:
#                  Series_Title Certificate
# 0    The Shawshank Redemption           A
# 1               The Godfather           A
# 2             The Dark Knight          UA
# 3      The Godfather: Part II           A
# 4                12 Angry Men           U
# ..                        ...         ...
# 995    Breakfast at Tiffany's           A
# 996                     Giant           G
# 997     From Here to Eternity      Passed
# 998                  Lifeboat         NaN
# 999              The 39 Steps         NaN
#
# [1000 rows x 2 columns]

# %%
imdb_pandas.Released_Year.dtype
# Out:
# dtype('O')

# %%
imdb_pandas.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
imdb_pandas.Certificate.unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
imdb_pandas['Released_Year'] = pd.to_numeric(imdb_pandas['Released_Year'], errors='coerce')

# %%
imdb_pandas["Released_Year"].mean()
# Out:
# 1991.2172172172172

# %%
imdb_pandas["Released_Year"].mode()
# Out:
# 0    2014.0
# Name: Released_Year, dtype: float64

# %%
imdb_pandas["Released_Year"].std()
# Out:
# 23.2970248443242

# %%
imdb_pandas['Meta_score'] = pd.to_numeric(imdb_pandas['Meta_score'], errors='coerce')

# %%
imdb_pandas['Meta_score'].mode()
# Out:
# 0    76.0
# Name: Meta_score, dtype: float64

# %%
imdb_pandas['Meta_score'].mean()
# Out:
# 77.97153024911032

# %%
import numpy as np

# %%
imdb_np
# Out:
# array([['https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg',
#         'The Shawshank Redemption', '1994', ..., 'William Sadler',
#         2343110, '28,341,469'],
#        ['https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg',
#         'The Godfather', '1972', ..., 'Diane Keaton', 1620367,
#         '134,966,411'],
#        ['https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#         'The Dark Knight', '2008', ..., 'Michael Caine', 2303232,
#         '534,858,444'],
#        ...,
#        ['https://m.media-amazon.com/images/M/MV5BM2U3YzkxNGMtYWE0YS00ODk0LTk1ZGEtNjk3ZTE0MTk4MzJjXkEyXkFqcGdeQXVyNDk0MDg4NDk@._V1_UX67_CR0,0,67,98_AL_.jpg',
#         'From Here to Eternity', '1953', ..., 'Donna Reed', 43374,
#         '30,500,000'],
# ...

# %%
released_year_column_index = 2
released_year = imdb_np[:, released_year_column_index]
numeric_released_year = [float(year) for year in released_year if year.isdigit()]
mean_released_year = np.mean(numeric_released_year)

mean_released_year
# Out:
# 1991.2172172172172

# %%
median_released_year = np.median(numeric_released_year)
median_released_year
# Out:
# 1999.0

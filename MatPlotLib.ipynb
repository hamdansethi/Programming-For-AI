# %% [markdown]
# <a href="https://colab.research.google.com/github/hamdansethi/Programming-For-AI/blob/main/MatPlotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(2,3), columns=["First", "Second", "Third"], index=["a", "b"])
df
# Out:
#       First    Second     Third
# a -0.165590  0.471559 -0.048102
# b  0.120831  0.346409  0.371498

# %%
df.index
# Out:
# Index(['a', 'b'], dtype='object')

# %%
df.columns
# Out:
# Index(['First', 'Second', 'Third'], dtype='object')

# %%
df=pd.DataFrame([{"Wage" : 1000, "Name" : "Jack", "Age" : 21}, {"Wage" : 1500, "Name" : "John", "Age" : 29}])
df
# Out:
#    Wage  Name  Age
# 0  1000  Jack   21
# 1  1500  John   29

# %%
df = pd.DataFrame([[1000, "Jack", 21], [1500, "John", 29]], columns=["Wage", "Name", "Age"])
df
# Out:
#    Wage  Name  Age
# 0  1000  Jack   21
# 1  1500  John   29

# %% [markdown]
#     Population       Total      area
#     Helsinki         643272     715.48
#     Espoo            279044     528.03
#     Tampere          231853     689.59
#     Vantaa           223027     240.35
#     Oulu             201810     3817.52

# %%
house = '/content/HouseRent.csv'

# %%
house2 = '/content/House_Rent_Dataset.csv'

# %%
house = pd.read_csv(house)
house2 = pd.read_csv(house2)

# %%
house.head()
# Out:
#     Posted On  BHK     Rent    Size            Floor    Area Type  \
# 0  2022-05-18    2  10000.0  1100.0  Ground out of 2   Super Area
# 1  2022-05-13    2  20000.0   800.0       1 out of 3   Super Area
# 2  2022-05-16    2  17000.0  1000.0       1 out of 3   Super Area
# 3  2022-07-04    2  10000.0   800.0       1 out of 2   Super Area
# 4  2022-05-09    2   7500.0   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# ...

# %%
house2.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
movies = '/content/imdb.csv'
movies = pd.read_csv(movies)

# %%
movies.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
movies.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
movies.shape
# Out:
# (1000, 16)

# %%
movies.info
# Out:
# <bound method DataFrame.info of                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
movies.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
movies.Certificate.info
# Out:
# <bound method Series.info of 0           A
# 1           A
# 2          UA
# 3           A
# 4           U
#         ...
# 995         A
# 996         G
# 997    Passed
# 998       NaN
# 999       NaN
# Name: Certificate, Length: 1000, dtype: object>

# %%
movies.IMDB_Rating.describe
# Out:
# <bound method NDFrame.describe of 0      9.3
# 1      9.2
# 2      9.0
# 3      9.0
# 4      9.0
#       ...
# 995    7.6
# 996    7.6
# 997    7.6
# 998    7.6
# 999    7.6
# Name: IMDB_Rating, Length: 1000, dtype: float64>

# %%
condition = movies["Director"] == "Christopher Nolan"
print(movies[condition])
print(condition)
# Out:
#                                            Poster_Link           Series_Title  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...        The Dark Knight
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...              Inception
# 21   https://m.media-amazon.com/images/M/MV5BZjdkOT...           Interstellar
# 36   https://m.media-amazon.com/images/M/MV5BMjA4ND...           The Prestige
# 63   https://m.media-amazon.com/images/M/MV5BMTk4OD...  The Dark Knight Rises
# 69   https://m.media-amazon.com/images/M/MV5BZTcyNj...                Memento
# 155  https://m.media-amazon.com/images/M/MV5BOTY4Yj...          Batman Begins
# 573  https://m.media-amazon.com/images/M/MV5BN2YyZj...                Dunkirk
#
#     Released_Year Certificate  Runtime                      Genre  \
# 2            2008          UA  152 min       Action, Crime, Drama
# 8            2010          UA  148 min  Action, Adventure, Sci-Fi
# 21           2014          UA  169 min   Adventure, Drama, Sci-Fi
# ...

# %%
movies[movies["Released_Year"] >= "2003" ]
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 19   https://m.media-amazon.com/images/M/MV5BYWZjMj...
# ..                                                 ...
# 937  https://m.media-amazon.com/images/M/MV5BMTUzND...
# 938  https://m.media-amazon.com/images/M/MV5BMjA4Mj...
# 940  https://m.media-amazon.com/images/M/MV5BMTMxNz...
# 942  https://m.media-amazon.com/images/M/MV5BODNiZm...
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...
#
#                                       Series_Title Released_Year Certificate  \
# 2                                  The Dark Knight          2008          UA
# 5    The Lord of the Rings: The Return of the King          2003           U
# ...

# %%
movies[movies["Released_Year"] >= "2003" ].head()
# Out:
#                                           Poster_Link  \
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 18  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 19  https://m.media-amazon.com/images/M/MV5BYWZjMj...
#
#                                      Series_Title Released_Year Certificate  \
# 2                                 The Dark Knight          2008          UA
# 5   The Lord of the Rings: The Return of the King          2003           U
# 8                                       Inception          2010          UA
# 18                                       Hamilton          2020       PG-13
# 19                                   Gisaengchung          2019           A
#
#     Runtime                      Genre  IMDB_Rating  \
# 2   152 min       Action, Crime, Drama          9.0
# 5   201 min   Action, Adventure, Drama          8.9
# ...

# %%
movies[movies["Director"] != "Christopher Nolan"].head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 3                         The Godfather: Part II          1974           A
# 4                                   12 Angry Men          1957           U
# 5  The Lord of the Rings: The Return of the King          2003           U
#
#    Runtime                     Genre  IMDB_Rating  \
# 0  142 min                     Drama          9.3
# 1  175 min              Crime, Drama          9.2
# ...

# %%
movies[movies["IMDB_Rating"] >= 8].head(3)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#                Director           Star1           Star2          Star3  \
# ...

# %%
movies[movies["IMDB_Rating"] >= 8].tail(3)
# Out:
#                                            Poster_Link  \
# 460  https://m.media-amazon.com/images/M/MV5BYmFlOW...
# 461  https://m.media-amazon.com/images/M/MV5BMzg2MW...
# 462  https://m.media-amazon.com/images/M/MV5BMTEyMT...
#
#                        Series_Title Released_Year Certificate  Runtime  \
# 460                    The Thin Man          1934       TV-PG   91 min
# 461  All Quiet on the Western Front          1930           U  152 min
# 462            Bronenosets Potemkin          1925         NaN   75 min
#
#                         Genre  IMDB_Rating  \
# 460    Comedy, Crime, Mystery          8.0
# 461                Drama, War          8.0
# 462  Drama, History, Thriller          8.0
#
#                                               Overview  Meta_score  \
# 460  Former detective Nick Charles and his wealthy ...        86.0
# 461  A German youth eagerly enters World War I, but...        91.0
# 462  In the midst of the Russian Revolution of 1905...        97.0
#
# ...

# %%
movies[movies["Director"].isin(["Christopher Nolan", "Ridely Scott"])].head()
# Out:
#                                           Poster_Link           Series_Title  \
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...        The Dark Knight
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...              Inception
# 21  https://m.media-amazon.com/images/M/MV5BZjdkOT...           Interstellar
# 36  https://m.media-amazon.com/images/M/MV5BMjA4ND...           The Prestige
# 63  https://m.media-amazon.com/images/M/MV5BMTk4OD...  The Dark Knight Rises
#
#    Released_Year Certificate  Runtime                      Genre  IMDB_Rating  \
# 2           2008          UA  152 min       Action, Crime, Drama          9.0
# 8           2010          UA  148 min  Action, Adventure, Sci-Fi          8.8
# 21          2014          UA  169 min   Adventure, Drama, Sci-Fi          8.6
# 36          2006           U  130 min     Drama, Mystery, Sci-Fi          8.5
# 63          2012          UA  164 min          Action, Adventure          8.4
#
# ...

# %%
movies[(movies["Director"] == "Christopher Nolan") | (movies["Director"] == "Ridely Scott")].head()
# Out:
#                                           Poster_Link           Series_Title  \
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...        The Dark Knight
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...              Inception
# 21  https://m.media-amazon.com/images/M/MV5BZjdkOT...           Interstellar
# 36  https://m.media-amazon.com/images/M/MV5BMjA4ND...           The Prestige
# 63  https://m.media-amazon.com/images/M/MV5BMTk4OD...  The Dark Knight Rises
#
#    Released_Year Certificate  Runtime                      Genre  IMDB_Rating  \
# 2           2008          UA  152 min       Action, Crime, Drama          9.0
# 8           2010          UA  148 min  Action, Adventure, Sci-Fi          8.8
# 21          2014          UA  169 min   Adventure, Drama, Sci-Fi          8.6
# 36          2006           U  130 min     Drama, Mystery, Sci-Fi          8.5
# 63          2012          UA  164 min          Action, Adventure          8.4
#
# ...

# %%
movies[(movies["Director"] == "Christopher Nolan") & (movies["IMDB_Rating"] >= 8)].head()
# Out:
#                                           Poster_Link           Series_Title  \
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...        The Dark Knight
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...              Inception
# 21  https://m.media-amazon.com/images/M/MV5BZjdkOT...           Interstellar
# 36  https://m.media-amazon.com/images/M/MV5BMjA4ND...           The Prestige
# 63  https://m.media-amazon.com/images/M/MV5BMTk4OD...  The Dark Knight Rises
#
#    Released_Year Certificate  Runtime                      Genre  IMDB_Rating  \
# 2           2008          UA  152 min       Action, Crime, Drama          9.0
# 8           2010          UA  148 min  Action, Adventure, Sci-Fi          8.8
# 21          2014          UA  169 min   Adventure, Drama, Sci-Fi          8.6
# 36          2006           U  130 min     Drama, Mystery, Sci-Fi          8.5
# 63          2012          UA  164 min          Action, Adventure          8.4
#
# ...

# %%
movies[(movies["Released_Year"] >= "2005") & (movies["Released_Year"] <= "2008") & (movies["IMDB_Rating"] >= 8) & (movies.Gross.quantile(0.25) < movies.Gross)].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-4b3e55c89d3a> in <cell line: 1>()
# ----> 1 movies[(movies["Released_Year"] >= "2005") & (movies["Released_Year"] <= "2008") & (movies["IMDB_Rating"] >= 8) & (movies.Gross.quantile(0.25) < movies.Gross)].head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in quantile(self, q, interpolation)
#    2885         df = self.to_frame()
#    2886
# -> 2887         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2888         if result.ndim == 2:
#    2889             result = result.iloc[:, 0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   12144             # error: List item 0 has incompatible type "float | ExtensionArray |
# ...

# %%
movies[(movies["IMDB_Rating"] >= 8)].head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
movies['Released_Year'] = pd.to_numeric(movies['Released_Year'], errors='coerce')
movies['Gross'] = pd.to_numeric(movies['Gross'], errors='coerce')

movies[(movies["Released_Year"] >= 2005) & (movies["Released_Year"] <= 2008) & (movies["IMDB_Rating"] >= 8) & (movies.Gross.quantile(0.5) < movies.Gross)].head()
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %%
movies[(movies["Released_Year"] >= 1950) &
       (movies["Released_Year"] <= 2050) &
       (movies["IMDB_Rating"] >= 5) &
       (movies["Gross"] < movies["Gross"].quantile(0.20))]
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %%
movies[(movies["Released_Year"] >= 1950) &
       (movies["Released_Year"] <= 2050) &
       (movies["IMDB_Rating"] >= 5)
       ]
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 993  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption         1994.0           A  142 min
# 1               The Godfather         1972.0           A  175 min
# 2             The Dark Knight         2008.0          UA  152 min
# ...

# %%
movies[(movies["Gross"] >= movies["Gross"].quantile(.25))]
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %%
print(movies["Gross"].dtype)
# Out:
# float64

# %%
movies["IMDB_Rating"].dtype
# Out:
# dtype('float64')

# %%
movies[(movies["Released_Year"].isin(range(2005,2010)))  &
       (movies["IMDB_Rating"] >= 5)
       ]
# Out:
#                                            Poster_Link          Series_Title  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...       The Dark Knight
# 36   https://m.media-amazon.com/images/M/MV5BMjA4ND...          The Prestige
# 37   https://m.media-amazon.com/images/M/MV5BMTI1MT...          The Departed
# 64   https://m.media-amazon.com/images/M/MV5BNTkyOG...              3 Idiots
# 65   https://m.media-amazon.com/images/M/MV5BMDhjZW...      Taare Zameen Par
# ..                                                 ...                   ...
# 928  https://m.media-amazon.com/images/M/MV5BNWMxYT...                   300
# 929  https://m.media-amazon.com/images/M/MV5BMjRjOT...           Match Point
# 930  https://m.media-amazon.com/images/M/MV5BY2IzNG...              Watchmen
# 931  https://m.media-amazon.com/images/M/MV5BMTYzZW...           Lord of War
# 933  https://m.media-amazon.com/images/M/MV5BMjA0Mj...  Synecdoche, New York
#
# ...

# %%
date = '20/10/24'
d, m ,y = date.split('/')
print(f'{d} {m},20{y}')
# Out:
# 20 10,2024

# %%
print(movies["No_of_Votes"].isnull().sum())
# Out:
# 0

# %%
movies_cleaned = movies.dropna(subset=["Gross"])
filtered_movies = movies_cleaned[(movies_cleaned["Gross"] >= movies_cleaned["Gross"].quantile(0.25))]
print(filtered_movies)
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %%
movies[(movies["No_of_Votes"] >= movies["No_of_Votes"].quantile(.90))]
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# ..                                                 ...
# 652  https://m.media-amazon.com/images/M/MV5BMDdmZG...
# 737  https://m.media-amazon.com/images/M/MV5BMzA2ND...
# 745  https://m.media-amazon.com/images/M/MV5BNjE5Mz...
# 750  https://m.media-amazon.com/images/M/MV5BNGQwZj...
# 928  https://m.media-amazon.com/images/M/MV5BNWMxYT...
#
#                                       Series_Title  Released_Year Certificate  \
# 0                         The Shawshank Redemption         1994.0           A
# 1                                    The Godfather         1972.0           A
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# Bar Graphs
#
# Scatter Plots
#
# Pie Charts
#
# Histogram
#
# Box Plot

# %%
a=np.array([2, 5, 7, 4, 7, 0, 3, 1, 9, 2])

# %%
plt.plot(a)
plt.title("My first figure")
plt.xlabel("My x-axis")
plt.ylabel("My y-axis")
plt.show()

# %%
x = np.array([2,4,6,7])
y = np.array([4,3,5,1])
plt.plot(x)
plt.plot(y)
plt.title("My first figure")
plt.xlabel("My x-axis")
plt.ylabel("My y-axis")
plt.show()

# %%
fig, ax = plt.subplots(2,2)
print(ax.shape)
ax[0,0].plot(np.arange(6))          # top left
ax[0,1].plot(np.arange(6,0,-1))     # top right
ax[1,0].plot((-1)**np.arange(6))    # bottom left
ax[1,1].plot((-1)**np.arange(1,7))  # bottom right
plt.show()
# Out:
# (2, 2)

# %% [markdown]
# Continuous Variable
#
# Categorical Variable

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.title("First Figure")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],[20,40,60,80])
plt.title("First Figure")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.figure(figsize=(50,5))
plt.plot([1,2,3,4],[1,4,9,16])
plt.title("First Figure")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.figure(figsize=(5,20))
plt.plot([1,2,3,4],[1,4,9,16])
plt.title("First Figure")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot([1,2,3,4],[1,4,9,16], "go")
plt.title("First Figure")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot([1,2,3,4],[1,4,9,16])
plt.plot([1,2,3,4],[1,4,9,16], "go")
plt.title("First Figure")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot([1,2,3,4],[1,4,9,16], "cyan")
plt.title("First Figure")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x = np.arange(1, 5)
y = x**3

plt.plot([1,2,3,4], [1,4,9,16], "yo", x, y, "r*")

plt.title("Second Fig")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.subplot(1,2,1) # r , c , i
plt.plot([1,2,3,4],[1,4,9,16])
plt.title("First Figure")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.subplot(1,2,2)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
z = [20, 40, 60, 80]

ax.plot(x, y, z)

ax.set_title("First Figure")
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_zlabel("z-axis")

plt.show()

# %%
from bokeh.plotting import figure, show

# %%
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# %%
p = figure(title="Simple line example", x_axis_label='x', y_axis_label='y')
p.line(x, y, legend_label="Temp.", line_width=2)
show(p)

# %%
code = """
from bokeh.plotting import figure, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# create a new plot with a title and axis labels
p = figure(title="Simple line example", x_axis_label="x", y_axis_label="y")

# add a line renderer with legend and line thickness
p.line(x, y, legend_label="Temp.", line_width=2)

# show the results
show(p)
"""

# Specify the filename
filename = "/content/my_code.py"

# Open the file in write mode and save the code
with open(filename, "w") as file:
    file.write(code)

print(f"Code saved to {filename}")
# Out:
# Code saved to /content/my_code.py

# %%
from IPython.display import display, HTML

# Path to your HTML file
html_file_path = '/content/my_code.html'

# Read the HTML file
with open(html_file_path, 'r') as file:
    html_content = file.read()

# Display the HTML content in Colab
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <title>Bokeh Plot</title>
#     <style>
#       html, body {
#         box-sizing: border-box;
#         display: flow-root;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#     </style>
#     <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-3.6.2.min.js"></script>
#     <script type="text/javascript">
#         Bokeh.set_log_level("info");
#     </script>
#   </head>
#   <body>
#     <div id="c405b614-40b2-44d5-820a-913dc9606541" data-root-id="p1001" style="display: contents;"></div>
#
#     <script type="application/json" id="e37c9772-4f45-4e63-826f-290a040c30cb">
# ...
